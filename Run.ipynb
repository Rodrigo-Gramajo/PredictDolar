# %%
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor

with open("BlueDiarioApi copy.ipynb") as f:
    nb = nbformat.read(f, as_version=4)

ep = ExecutePreprocessor(timeout=600, kernel_name='python3')
ep.preprocess(nb, {'metadata': {'path': './'}})
# Out:
# ---------------------------------------------------------------------------
# CellExecutionError                        Traceback (most recent call last)
# c:\Users\rodri\OneDrive\Escritorio\Digital\Dolar V4\PredictDolar\Run.ipynb Cell 1 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/rodri/OneDrive/Escritorio/Digital/Dolar%20V4/PredictDolar/Run.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a>     nb = nbformat.read(f, as_version=4)
#       <a href='vscode-notebook-cell:/c%3A/Users/rodri/OneDrive/Escritorio/Digital/Dolar%20V4/PredictDolar/Run.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> ep = ExecutePreprocessor(timeout=600, kernel_name='python3')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rodri/OneDrive/Escritorio/Digital/Dolar%20V4/PredictDolar/Run.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> ep.preprocess(nb, {'metadata': {'path': './'}})
#
# File c:\Users\rodri\anaconda3.1\envs\dhdsblend2021\lib\site-packages\nbconvert\preprocessors\execute.py:84, in ExecutePreprocessor.preprocess(self, nb, resources, km)
#      82     self.nb.metadata['language_info'] = info_msg['content']['language_info']
#      83     for index, cell in enumerate(self.nb.cells):
# ---> 84         self.preprocess_cell(cell, resources, index)
#      85 self.set_widgets_metadata()
#      87 return self.nb, self.resources
#
# File c:\Users\rodri\anaconda3.1\envs\dhdsblend2021\lib\site-packages\nbconvert\preprocessors\execute.py:105, in ExecutePreprocessor.preprocess_cell(self, cell, resources, index)
#      90 """
#      91 Override if you want to apply some preprocessing to each cell.
#      92 Must return modified cell and resource dictionary.
#    (...)
#     102     Index of the cell being processed
#     103 """
#     104 self._check_assign_resources(resources)
# --> 105 cell = self.execute_cell(cell, index, store_history=True)
#     106 return cell, self.resources
#
# File c:\Users\rodri\anaconda3.1\envs\dhdsblend2021\lib\site-packages\nbclient\util.py:84, in run_sync.<locals>.wrapped(*args, **kwargs)
#      83 def wrapped(*args, **kwargs):
# ---> 84     return just_run(coro(*args, **kwargs))
#
# File c:\Users\rodri\anaconda3.1\envs\dhdsblend2021\lib\site-packages\nbclient\util.py:62, in just_run(coro)
#      60     nest_asyncio.apply()
#      61     check_patch_tornado()
# ---> 62 return loop.run_until_complete(coro)
#
# File c:\Users\rodri\anaconda3.1\envs\dhdsblend2021\lib\site-packages\nest_asyncio.py:89, in _patch_loop.<locals>.run_until_complete(self, future)
#      86 if not f.done():
#      87     raise RuntimeError(
#      88         'Event loop stopped before Future completed.')
# ---> 89 return f.result()
#
# File c:\Users\rodri\anaconda3.1\envs\dhdsblend2021\lib\asyncio\futures.py:178, in Future.result(self)
#     176 self.__log_traceback = False
#     177 if self._exception is not None:
# --> 178     raise self._exception
#     179 return self._result
#
# File c:\Users\rodri\anaconda3.1\envs\dhdsblend2021\lib\asyncio\tasks.py:280, in Task.__step(***failed resolving arguments***)
#     276 try:
#     277     if exc is None:
#     278         # We use the `send` method directly, because coroutines
#     279         # don't have `__iter__` and `__next__` methods.
# --> 280         result = coro.send(None)
#     281     else:
#     282         result = coro.throw(exc)
#
# File c:\Users\rodri\anaconda3.1\envs\dhdsblend2021\lib\site-packages\nbclient\client.py:965, in NotebookClient.async_execute_cell(self, cell, cell_index, execution_count, store_history)
#     963 if execution_count:
#     964     cell['execution_count'] = execution_count
# --> 965 await self._check_raise_for_error(cell, cell_index, exec_reply)
#     966 self.nb['cells'][cell_index] = cell
#     967 return cell
#
# File c:\Users\rodri\anaconda3.1\envs\dhdsblend2021\lib\site-packages\nbclient\client.py:862, in NotebookClient._check_raise_for_error(self, cell, cell_index, exec_reply)
#     860 await run_hook(self.on_cell_error, cell=cell, cell_index=cell_index)
#     861 if not cell_allows_errors:
# --> 862     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
#
# CellExecutionError: An error occurred while executing the following cell:
# ------------------
# df.to_excel("data/xlsx/prueba.xlsx")
# ------------------
#
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df.to_excel("data/xlsx/prueba.xlsx")
#
# File c:\Users\rodri\anaconda3.1\envs\dhdsblend2021\lib\site-packages\pandas\core\generic.py:2026, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2013 from pandas.io.formats.excel import ExcelFormatter
#    2015 formatter = ExcelFormatter(
#    2016     df,
#    2017     na_rep=na_rep,
#    (...)
#    2024     inf_rep=inf_rep,
#    2025 )
# -> 2026 formatter.write(
#    2027     excel_writer,
#    2028     sheet_name=sheet_name,
#    2029     startrow=startrow,
#    2030     startcol=startcol,
#    2031     freeze_panes=freeze_panes,
#    2032     engine=engine,
#    2033 )
#
# File c:\Users\rodri\anaconda3.1\envs\dhdsblend2021\lib\site-packages\pandas\io\formats\excel.py:730, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     728     need_save = False
#     729 else:
# --> 730     writer = ExcelWriter(stringify_path(writer), engine=engine)
#     731     need_save = True
#     733 formatted_cells = self.get_formatted_cells()
#
# File c:\Users\rodri\anaconda3.1\envs\dhdsblend2021\lib\site-packages\pandas\io\excel\_openpyxl.py:18, in _OpenpyxlWriter.__init__(self, path, engine, mode, **engine_kwargs)
#      16 def __init__(self, path, engine=None, mode="w", **engine_kwargs):
#      17     # Use the openpyxl module as the Excel writer.
# ---> 18     from openpyxl.workbook import Workbook
#      20     super().__init__(path, mode=mode, **engine_kwargs)
#      22     if self.mode == "a":  # Load from existing workbook
#
# ModuleNotFoundError: No module named 'openpyxl'
# ModuleNotFoundError: No module named 'openpyxl'
